# %% [markdown]
# # Aula 3
# ## Condicionais

# %% [markdown]
# ## **Parte teórica**

# %% [markdown]
# ### **1 - Estrutura condicional**
# - O que é uma estrutura condicional?
#
#      Essa estrutura nos permite dividir o fluxo de um programa em diferentes caminhos, e para que isso ocorra iremos usar Operadores Lógicos e Relacionais
#
#      ![image.png](data:image/png;base64,...)
#
#
# ---
#
# ### **1 - Tipos de operadores**
#   - **Operdores relacionais:**
#
#   Os operadores relacionais comparam duas expressões e retornam um valor lógico dependendo da operação, True ou False (Verdadeiro ou Falso), abaixo alguns exemplos:
#
#
#     - 5=5 (True)
#     - 5<=5 (False)
#     - 5>=5 (False)
#     - 5!=5 (False)
#
#   - **Operdores lógicos:**
#
#   Os operadores lógicos realizam operações do tipo logica, usando as palavras reservadas, AND, OR e NOT, abaixo alguns exemplos:
#
#
#     - 5=5 or 5!=5 (True)
#     - 5=5 and 5!=5 (False)
#     - not 5=5 (False)
#
#   - O que seria IF/Else?
#
#   Esses operadores é usando para fazer a validação das informações, e retornar o bloco do código correspondente a validação,
#
#   Como no exemplo abaixo, o Homer se encontra na dúvida, se o 5 é igual a 5, e para resolver isso é muito fácil:
#   ![image.png](data:image/png;base64,...)

# %%
if 5==5:
  print("Rosquinha")
else:
  print("Stop")

# %% [markdown]
#  - O que seria IF/Elif/Else?
#
#   Além do IF e do Else no Python também usamos o Elif para fazer múltiplas validações, como no exemplo abaixo:

# %%
mes = 5

if mes == 2:
  print("Fevereiro")
elif mes == 3:
  print("Março")
else:
  print("Esse mês não existe!")

# %% [markdown]
# ## **Parte prática**

# %% [markdown]
# Operadores Relacionais

# %%
5 == 5

# %%
5 >= 5

# %%
5 <= 5

# %%
5 != 5

# %% [markdown]
# Operadores lógicos

# %%
5 == 5 and 5 !=5

# %%
5 == 5 or 5 !=5

# %%
not 5 == 5

# %% [markdown]
# If

# %%
if 5 == 5:
    print("Número par")

# %% [markdown]
# If-else

# %%
if 5 == 5:
    print("número ímpar")
else:
    print("Talvez não seja um número ímpar")

# %% [markdown]
# If-else elif

# %%
mes = 5

if mes == 2:
    print("The month is february")
elif mes == 3:
    print("The month is march")
else:
    print("The month is not known yet")

# %% [markdown]
# Implementação no código da aula anterior

# %%
class Robot:
    def __init__(self, name, color_code):
      self.name = name
      self.color_code = color_code
      self.energy = 100
      self.on = True
      print("Hello World")
    
    def great(self):
        print("My name is:", self.name)
        print("My color is:", self.color_code)
        print("My energy is:", self.energy)
        print("My status is:", self.on)

    def turn_on(self):
      if self.on >= 0:
        print("On")
      else:
        print("Off")



friday = Robot("Friday", "25")
friday.great()
friday.turn_on()

# %%
class Robot:
    def __init__(self, name, color_code):
      self.name = name
      self.color_code = color_code
      self.energy = 100
      self.on = True
      print("Hello World")
    
    def great(self):
        print("My name is:", self.name)
        print("My color is:", self.color_code)
        print("My energy is:", self.energy)
        print("My status is:", self.on)

    def turn_on(self):
      if self.on >= 0:
        return True
      else:
        return False



friday = Robot("Friday", "25")
friday.great()
on = friday.turn_on()
print(on)

# %% [markdown]
# ## **Código para implementar no projeto final do Robô**

# %% [markdown]
# - Código desenvolvido com o conhecimento e exemplos passados durante a aula três.

# %%
def is_on(self):
        return self.energy >= 0
